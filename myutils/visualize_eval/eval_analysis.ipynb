# %%
import sys, os
sys.path.insert(0, os.getcwd())

import numpy as np
import time

# %%
import importlib
import viz_utils
importlib.reload(viz_utils)
from viz_utils import boxplots_by_dataset_compare

import experiment
importlib.reload(experiment)
from experiment import Experiment

# %%
data_path = '/'.join(os.getcwd().split('/')[:-2] + ['train_outputs'])

# %% [markdown]
# ## Experiments

# %% [markdown]
# ### Baseline model with their weights

# %%
Experiment('baseline').cleanup()

# %%
baseline = Experiment('baseline')
baseline.load_eval_inference_info(os.path.join(data_path, "2181388/Test_record/ACL_ViT16_Exp_ACL_v1/numpy"))
baseline.load_eval_inference_info(os.path.join(data_path, "2184833/Test_record/ACL_ViT16_Exp_ACL_v1/numpy"))
baseline.load_eval_metrics(os.path.join(data_path, "2184833/Test_record/ACL_ViT16_Exp_ACL_v1/tensorboard"))
# baseline.load_eval_inference_info_noisy(os.path.join(data_path, "2170954/Test_record_noisy/ACL_ViT16_Exp_ACL_v1/numpy"))

# %%
dataset = 'vggss'
seg_item = 'm_i' # v_d|m_i|v_i|v_f
thresh='max_q3_separate' # max_neg|max_neg_plus_10|max_q2_pos|max_q3_all|max_q3_separate

# %%
# boxplots_by_dataset_compare(
#     [Experiment('baseline')],
#     [20],
#     dataset_name=dataset,
#     seg_item=seg_item,
#     th_name=thresh,
#     min_max='max'
# )

# %%
baseline.print_metrics('adap', 'm_i')

# %%
baseline.print_metrics('max_q3_separate', 'm_i')

# %%
baseline.print_metrics_noisy('best', 'max_neg', 'm_i')

# %%
baseline.print_metrics_noisy('best', '0.5', 'v_d')

# %%
baseline.print_metrics_noisy('best', 'None', 'm_i')

# %%
baseline.print_metrics('best', '0.5', 'm_i')

# %%
baseline.boxplots_by_dataset('vggss', ['best'], 'max_q3_separate', 'm_i')

# %%
baseline.boxplots_by_dataset('vggss', ['best'], 'max_q3_separate', 'v_d')

# %%
# baseline.boxplots_by_dataset('avatar_one', ['best'], 'max_neg_plus_10', 'v_d')
# for dataset in baseline.infer_info['dataset'].unique():
#     for thr in baseline.thresholds['best']['m_i'].keys():
#         for it in ['m_i', 'v_d']:
#             baseline.boxplots_by_dataset(dataset, list(baseline.thresholds.keys()), th_name=thr, seg_item=it)
#             time.sleep(1)

# %%
baseline.plot_all_metrics('best', 'adap', 'm_i')

# %%
baseline.plot_all_metrics('best', 'adap', 'v_d')

# %% [markdown]
# ### ExpV1 Batch_size=16

# %%
# Experiment('exp_v1_B16').cleanup()
exp_v1_B16 = Experiment('exp_v1_B16')
exp_v1_B16.load_eval_inference_info(os.path.join(data_path, "2074301-full/2181729/Test_record/ACL_ViT16_aclifa_2gpu/numpy"))
exp_v1_B16.load_eval_inference_info(os.path.join(data_path, "2074301-full/2185955/Test_record/ACL_ViT16_aclifa_2gpu/numpy"))
exp_v1_B16.load_eval_metrics(os.path.join(data_path, "2074301-full/2185955/Test_record/ACL_ViT16_aclifa_2gpu/tensorboard"))

# %%
exp_v1_B16.print_metrics('adap', 'm_i')

# %%
exp_v1_B16.print_metrics('max_q3_separate', 'v_d')

# %%
for dataset in exp_v1_B16.infer_info['dataset'].unique():
    for thr in exp_v1_B16.thresholds[0]['m_i'].keys():
        for it in ['m_i', 'v_d']:
            exp_v1_B16.boxplots_by_dataset(dataset, list(exp_v1_B16.thresholds.keys()), th_name=thr, seg_item=it)
            time.sleep(1)

# %%
# for i in range(20):
#     exp_v1_B16.plot_all_metrics(i, 'adap', 'v_d')

# %% [markdown]
# ### ExpV1 Batch_size=32

# %%
exp_v1_B32 = Experiment('exp_v1_B32')
exp_v1_B32.load_eval_inference_info(os.path.join(data_path, "pirineus3/2064866/2182142/Test_record/ACL_ViT16_aclifa_2gpu/numpy"))
exp_v1_B32.load_eval_inference_info(os.path.join(data_path, "pirineus3/2064866/2186728/Test_record/ACL_ViT16_aclifa_2gpu/numpy"))
exp_v1_B32.load_eval_metrics(os.path.join(data_path, "pirineus3/2064866/2186728/Test_record/ACL_ViT16_aclifa_2gpu/tensorboard"))

# %%
exp_v1_B32.print_metrics('adap', 'm_i')

# %%
exp_v1_B32.print_metrics('max_q3_separate', 'm_i')

# %%
# for dataset in exp_v1_B32.infer_info['dataset'].unique():
#     for thr in exp_v1_B32.thresholds[0]['m_i'].keys():
#         for it in ['m_i', 'v_d']:
#             exp_v1_B32.boxplots_by_dataset(dataset, list(exp_v1_B32.thresholds.keys()), th_name=thr, seg_item=it)

# %%
for i in range(20):
    exp_v1_B32.plot_all_metrics(i, 'adap', 'm_i')

# %% [markdown]
# ### ExpV2 Batch_size=16

# %%
exp_v2_B16 = Experiment('exp_v2_B16')
exp_v2_B16.load_eval_inference_info(os.path.join(data_path, "pirineus3/2168632/2181900/Test_record/ACL_ViT16_aclifa_2gpu/numpy"))
exp_v2_B16.load_eval_inference_info(os.path.join(data_path, "pirineus3/2168632/2186726/Test_record/ACL_ViT16_aclifa_2gpu/numpy"))
exp_v2_B16.load_eval_metrics(os.path.join(data_path, "pirineus3/2168632/2186726/Test_record/ACL_ViT16_aclifa_2gpu/tensorboard"))

# %%
exp_v2_B16.print_metrics('adap', 'm_i')

# %%
exp_v2_B16.print_metrics('max_q3_separate', 'v_d')

# %%
# for dataset in exp_v2_B16.infer_info['dataset'].unique():
#     for thr in exp_v2_B16.thresholds[0]['m_i'].keys():
#         for it in ['m_i', 'v_d']:
#             exp_v2_B16.boxplots_by_dataset(dataset, list(exp_v2_B16.thresholds.keys()), th_name=thr, seg_item=it)

# %% [markdown]
# ### ExpV3 Batch_size=16

# %%
exp_v3_B16 = Experiment('exp_v3_B16')
exp_v3_B16.load_eval_inference_info(os.path.join(data_path, "pirineus3/2210849/2181901/Test_record/ACL_ViT16_aclifa_2gpu/numpy"))
exp_v3_B16.load_eval_inference_info(os.path.join(data_path, "pirineus3/2210849/2186727/Test_record/ACL_ViT16_aclifa_2gpu/numpy"))
exp_v3_B16.load_eval_metrics(os.path.join(data_path, "pirineus3/2210849/2186727/Test_record/ACL_ViT16_aclifa_2gpu/tensorboard"))

# %%
exp_v3_B16.print_metrics('adap', 'm_i')

# %%
exp_v3_B16.print_metrics('max_q3_separate', 'm_i')

# %%
for dataset in exp_v3_B16.infer_info['dataset'].unique():
    for thr in exp_v3_B16.thresholds[0]['m_i'].keys():
        for it in ['m_i', 'v_d']:
            exp_v3_B16.boxplots_by_dataset(dataset, list(exp_v3_B16.thresholds.keys()), th_name=thr, seg_item=it)

# %%
# plot_all_experiments(EXPERIMENTS)

# %% [markdown]
# ### ExpV4 Batch_size=16

# %%
exp_v4_B16 = Experiment('exp_v4_B16')
exp_v4_B16.load_eval_inference_info(os.path.join(data_path, "pirineus3/2271991/2184858/Test_record/ACL_ViT16_aclifa_2gpu/numpy"))
exp_v4_B16.load_eval_inference_info(os.path.join(data_path, "pirineus3/2271991/2186729/Test_record/ACL_ViT16_aclifa_2gpu/numpy"))
exp_v4_B16.load_eval_metrics(os.path.join(data_path, "pirineus3/2271991/2186729/Test_record/ACL_ViT16_aclifa_2gpu/tensorboard"))

# %%
exp_v4_B16.print_metrics('adap', 'm_i')

# %%
exp_v4_B16.print_metrics('max_q3_separate', 'v_d')

# %%
for dataset in exp_v4_B16.infer_info['dataset'].unique():
    for thr in exp_v4_B16.thresholds[0]['m_i'].keys():
        for it in ['m_i', 'v_d']:
            exp_v4_B16.boxplots_by_dataset(dataset, list(exp_v4_B16.thresholds.keys()), th_name=thr, seg_item=it)
