# %%
import sys, os
sys.path.insert(0, os.getcwd())

import numpy as np

# %%
import importlib
import viz_utils
importlib.reload(viz_utils)
from viz_utils import boxplots_by_dataset_compare

import experiment
importlib.reload(experiment)
from experiment import Experiment

# %%
data_path = '/'.join(os.getcwd().split('/')[:-2] + ['train_outputs'])

# %% [markdown]
# ## Experiments

# %% [markdown]
# ### Baseline model with their weights

# %%
Experiment('baseline').cleanup()

# %%
baseline = Experiment('baseline')
baseline.load_eval_metrics(os.path.join(data_path, "2170951/Test_record/ACL_ViT16_Exp_ACL_v1/tensorboard"))
baseline.load_eval_metrics(os.path.join(data_path, "2170954/Test_record_noisy/ACL_ViT16_Exp_ACL_v1/tensorboard"))
baseline.load_eval_inference_info(os.path.join(data_path, "2170951/Test_record/ACL_ViT16_Exp_ACL_v1/numpy"))
# baseline.load_eval_inference_info_noisy(os.path.join(data_path, "2170954/Test_record_noisy/ACL_ViT16_Exp_ACL_v1/numpy"))
baseline.thresholds = {
    20: {'m_i': {'max_neg': 0.6271, 'max_neg_plus_10': 0.6898, 'max_q3_all': 0.8546, 'max_q2_pos': 0.936, 'max_q3_separate': 0.8704}, 'v_d': {'max_neg': 0.617, 'max_neg_plus_10': 0.6786, 'max_q3_all': 0.6251, 'max_q2_pos': 0.6621, 'max_q3_separate': 0.6287}}
}

# %%
dataset = 'vggss'
seg_item = 'm_i' # v_d|m_i|v_i|v_f
thresh='max_q3_separate' # max_neg|max_neg_plus_10|max_q2_pos|max_q3_all|max_q3_separate

# %%
# boxplots_by_dataset_compare(
#     [Experiment('baseline')],
#     [20],
#     dataset_name=dataset,
#     seg_item=seg_item,
#     th_name=thresh,
#     min_max='max'
# )

# %%
baseline.print_metrics_noisy(20, 'max_neg', 'm_i')

# %%
baseline.print_metrics_noisy(20, '0.5', 'v_d')

# %%
baseline.print_metrics_noisy(20, 'None', 'm_i')

# %%
baseline.print_metrics(20, '0.5', 'm_i')

# %%
baseline.boxplots_by_dataset('vggss', [20], 'max_q3_separate', 'm_i')

# %%
baseline.boxplots_by_dataset('vggss', [20], 'max_q3_separate', 'v_d')

# %%
# baseline.boxplots_by_dataset('avatar_one', [20], 'max_neg_plus_10', 'v_d')
# for dataset in baseline.infer_info['dataset'].unique():
#     for thr in baseline.thresholds[20]['m_i'].keys():
#         for it in ['m_i', 'v_d']:
#             baseline.boxplots_by_dataset(dataset, list(baseline.thresholds.keys()), th_name=thr, seg_item=it)

# %%
baseline.plot_all_metrics(20, 'adap', 'm_i')

# %%
baseline.plot_all_metrics(20, 'adap', 'v_d')

# %% [markdown]
# ### ExpV1 Batch_size=16

# %%
exp_v1_B16 = Experiment('exp_v1_B16')
exp_v1_B16.load_eval_metrics(os.path.join(data_path, "2074301-full/2170945/Test_record/ACL_ViT16_aclifa_2gpu/tensorboard"))
# exp_v1_B16.load_eval_metrics(os.path.join(data_path, "2074301-full/xxxxxx/Test_record_noisy/ACL_ViT16_Exp_ACL_v2/tensorboard"))
exp_v1_B16.load_eval_inference_info(os.path.join(data_path, "2074301-full/2170945/Test_record/ACL_ViT16_aclifa_2gpu/numpy"))
exp_v1_B16.thresholds = {
    0: {'m_i': {'max_neg': 0.5786, 'max_neg_plus_10': 0.6365, 'max_q3_all': 0.8612, 'max_q2_pos': 0.5432, 'max_q3_separate': 0.9208}, 'v_d': {'max_neg': 0.5913, 'max_neg_plus_10': 0.6504, 'max_q3_all': 0.5981, 'max_q2_pos': 0.6113, 'max_q3_separate': 0.6025}},
    1: {'m_i': {'max_neg': 0.4791, 'max_neg_plus_10': 0.527, 'max_q3_all': 0.8854, 'max_q2_pos': 0.2902, 'max_q3_separate': 0.9487}, 'v_d': {'max_neg': 0.6076, 'max_neg_plus_10': 0.6684, 'max_q3_all': 0.6155, 'max_q2_pos': 0.6177, 'max_q3_separate': 0.6173}},
    2: {'m_i': {'max_neg': 0.8334, 'max_neg_plus_10': 0.9167, 'max_q3_all': 0.9365, 'max_q2_pos': 0.6136, 'max_q3_separate': 0.956}, 'v_d': {'max_neg': 0.602, 'max_neg_plus_10': 0.6622, 'max_q3_all': 0.6121, 'max_q2_pos': 0.6211, 'max_q3_separate': 0.6228}},
    3: {'m_i': {'max_neg': 0.7938, 'max_neg_plus_10': 0.8732, 'max_q3_all': 0.9268, 'max_q2_pos': 0.722, 'max_q3_separate': 0.947}, 'v_d': {'max_neg': 0.6041, 'max_neg_plus_10': 0.6645, 'max_q3_all': 0.6111, 'max_q2_pos': 0.6185, 'max_q3_separate': 0.6183}},
    4: {'m_i': {'max_neg': 0.7246, 'max_neg_plus_10': 0.797, 'max_q3_all': 0.9363, 'max_q2_pos': 0.785, 'max_q3_separate': 0.9413}, 'v_d': {'max_neg': 0.6038, 'max_neg_plus_10': 0.6642, 'max_q3_all': 0.614, 'max_q2_pos': 0.6225, 'max_q3_separate': 0.6233}},
    5: {'m_i': {'max_neg': 0.648, 'max_neg_plus_10': 0.7128, 'max_q3_all': 0.8951, 'max_q2_pos': 0.7807, 'max_q3_separate': 0.9346}, 'v_d': {'max_neg': 0.6032, 'max_neg_plus_10': 0.6635, 'max_q3_all': 0.6127, 'max_q2_pos': 0.6248, 'max_q3_separate': 0.6206}},
    6: {'m_i': {'max_neg': 0.5597, 'max_neg_plus_10': 0.6157, 'max_q3_all': 0.8783, 'max_q2_pos': 0.7404, 'max_q3_separate': 0.9248}, 'v_d': {'max_neg': 0.6013, 'max_neg_plus_10': 0.6614, 'max_q3_all': 0.6111, 'max_q2_pos': 0.6293, 'max_q3_separate': 0.6181}},
    7: {'m_i': {'max_neg': 0.6381, 'max_neg_plus_10': 0.7019, 'max_q3_all': 0.8898, 'max_q2_pos': 0.7906, 'max_q3_separate': 0.9042}, 'v_d': {'max_neg': 0.6044, 'max_neg_plus_10': 0.6649, 'max_q3_all': 0.6135, 'max_q2_pos': 0.632, 'max_q3_separate': 0.6202}},
    8: {'m_i': {'max_neg': 0.5975, 'max_neg_plus_10': 0.6572, 'max_q3_all': 0.8953, 'max_q2_pos': 0.7319, 'max_q3_separate': 0.9437}, 'v_d': {'max_neg': 0.607, 'max_neg_plus_10': 0.6677, 'max_q3_all': 0.6146, 'max_q2_pos': 0.6328, 'max_q3_separate': 0.619}},
    9: {'m_i': {'max_neg': 0.4444, 'max_neg_plus_10': 0.4888, 'max_q3_all': 0.8948, 'max_q2_pos': 0.7985, 'max_q3_separate': 0.9493}, 'v_d': {'max_neg': 0.6207, 'max_neg_plus_10': 0.6828, 'max_q3_all': 0.6288, 'max_q2_pos': 0.6353, 'max_q3_separate': 0.629}},
    10: {'m_i': {'max_neg': 0.7433, 'max_neg_plus_10': 0.8177, 'max_q3_all': 0.9171, 'max_q2_pos': 0.6425, 'max_q3_separate': 0.9459}, 'v_d': {'max_neg': 0.606, 'max_neg_plus_10': 0.6666, 'max_q3_all': 0.6143, 'max_q2_pos': 0.6452, 'max_q3_separate': 0.6211}},
    11: {'m_i': {'max_neg': 0.3927, 'max_neg_plus_10': 0.432, 'max_q3_all': 0.8563, 'max_q2_pos': 0.675, 'max_q3_separate': 0.9328}, 'v_d': {'max_neg': 0.6342, 'max_neg_plus_10': 0.6976, 'max_q3_all': 0.6584, 'max_q2_pos': 0.6415, 'max_q3_separate': 0.6588}},
    12: {'m_i': {'max_neg': 0.6731, 'max_neg_plus_10': 0.7404, 'max_q3_all': 0.9228, 'max_q2_pos': 0.7509, 'max_q3_separate': 0.9542}, 'v_d': {'max_neg': 0.6058, 'max_neg_plus_10': 0.6664, 'max_q3_all': 0.6139, 'max_q2_pos': 0.6386, 'max_q3_separate': 0.6189}},
    13: {'m_i': {'max_neg': 0.6576, 'max_neg_plus_10': 0.7234, 'max_q3_all': 0.9046, 'max_q2_pos': 0.7497, 'max_q3_separate': 0.9463}, 'v_d': {'max_neg': 0.6086, 'max_neg_plus_10': 0.6695, 'max_q3_all': 0.6166, 'max_q2_pos': 0.64, 'max_q3_separate': 0.6203}},
    14: {'m_i': {'max_neg': 0.7203, 'max_neg_plus_10': 0.7923, 'max_q3_all': 0.9385, 'max_q2_pos': 0.7484, 'max_q3_separate': 0.9655}, 'v_d': {'max_neg': 0.6047, 'max_neg_plus_10': 0.6651, 'max_q3_all': 0.6154, 'max_q2_pos': 0.6423, 'max_q3_separate': 0.6223}},
    15: {'m_i': {'max_neg': 0.3841, 'max_neg_plus_10': 0.4225, 'max_q3_all': 0.8073, 'max_q2_pos': 0.7795, 'max_q3_separate': 0.9125}, 'v_d': {'max_neg': 0.6408, 'max_neg_plus_10': 0.7049, 'max_q3_all': 0.6685, 'max_q2_pos': 0.6383, 'max_q3_separate': 0.669}},
    16: {'m_i': {'max_neg': 0.4205, 'max_neg_plus_10': 0.4625, 'max_q3_all': 0.8699, 'max_q2_pos': 0.7377, 'max_q3_separate': 0.94}, 'v_d': {'max_neg': 0.6453, 'max_neg_plus_10': 0.7098, 'max_q3_all': 0.6762, 'max_q2_pos': 0.642, 'max_q3_separate': 0.6766}},
    17: {'m_i': {'max_neg': 0.6482, 'max_neg_plus_10': 0.713, 'max_q3_all': 0.8949, 'max_q2_pos': 0.796, 'max_q3_separate': 0.9198}, 'v_d': {'max_neg': 0.6056, 'max_neg_plus_10': 0.6662, 'max_q3_all': 0.6153, 'max_q2_pos': 0.6418, 'max_q3_separate': 0.6226}},
    18: {'m_i': {'max_neg': 0.7009, 'max_neg_plus_10': 0.771, 'max_q3_all': 0.9089, 'max_q2_pos': 0.7704, 'max_q3_separate': 0.9338}, 'v_d': {'max_neg': 0.6054, 'max_neg_plus_10': 0.666, 'max_q3_all': 0.614, 'max_q2_pos': 0.6426, 'max_q3_separate': 0.62}},
    19: {'m_i': {'max_neg': 0.3911, 'max_neg_plus_10': 0.4302, 'max_q3_all': 0.82, 'max_q2_pos': 0.6739, 'max_q3_separate': 0.9246}, 'v_d': {'max_neg': 0.6427, 'max_neg_plus_10': 0.7069, 'max_q3_all': 0.6741, 'max_q2_pos': 0.6442, 'max_q3_separate': 0.6746}},
}

# %%
for i in exp_v1_B16.thresholds.keys():
    exp_v1_B16.print_metrics(i, 'adap', 'm_i')

# %%
for i in exp_v1_B16.thresholds.keys():
    exp_v1_B16.print_metrics(i, 'max_q3_separate', 'm_i')

# %%
# for dataset in exp_v1_B16.infer_info['dataset'].unique():
#     for thr in exp_v1_B16.thresholds[0]['m_i'].keys():
#         for it in ['m_i', 'v_d']:
#             exp_v1_B16.boxplots_by_dataset(dataset, list(exp_v1_B16.thresholds.keys()), th_name=thr, seg_item=it)

# %%
for i in range(20):
    exp_v1_B16.plot_all_metrics(i, 'adap', 'v_d')

# %% [markdown]
# ### ExpV1 Batch_size=32

# %%
exp_v1_B32 = Experiment('exp_v1_B32')
exp_v1_B32.load_eval_metrics(os.path.join(data_path, "pirineus3/2064866/2170947/Test_record/ACL_ViT16_aclifa_2gpu/tensorboard"))
# exp_v1_B32.load_eval_metrics(os.path.join(data_path, "pirineus3/2064866/Test_record_noisy/ACL_ViT16_Exp_ACL_v1/tensorboard"))
exp_v1_B32.load_eval_inference_info(os.path.join(data_path, "pirineus3/2064866/2170947/Test_record/ACL_ViT16_aclifa_2gpu/numpy"))

# %%
exp_v1_B32.thresholds = {
    0: {'m_i': {'max_neg': 0.609, 'max_neg_plus_10': 0.6699, 'max_q3_all': 0.8589, 'max_q2_pos': 0.8397, 'max_q3_separate': 0.8869}, 'v_d': {'max_neg': 0.6072, 'max_neg_plus_10': 0.668, 'max_q3_all': 0.6152, 'max_q2_pos': 0.6159, 'max_q3_separate': 0.6195}},
    1: {'m_i': {'max_neg': 0.4978, 'max_neg_plus_10': 0.5476, 'max_q3_all': 0.8384, 'max_q2_pos': 0.8376, 'max_q3_separate': 0.9109}, 'v_d': {'max_neg': 0.6028, 'max_neg_plus_10': 0.6631, 'max_q3_all': 0.6101, 'max_q2_pos': 0.6268, 'max_q3_separate': 0.6131}},
    2: {'m_i': {'max_neg': 0.625, 'max_neg_plus_10': 0.6875, 'max_q3_all': 0.8898, 'max_q2_pos': 0.8864, 'max_q3_separate': 0.939}, 'v_d': {'max_neg': 0.5994, 'max_neg_plus_10': 0.6593, 'max_q3_all': 0.6085, 'max_q2_pos': 0.6318, 'max_q3_separate': 0.6126}},
    3: {'m_i': {'max_neg': 0.4954, 'max_neg_plus_10': 0.5449, 'max_q3_all': 0.86, 'max_q2_pos': 0.8932, 'max_q3_separate': 0.9331}, 'v_d': {'max_neg': 0.601, 'max_neg_plus_10': 0.6611, 'max_q3_all': 0.6103, 'max_q2_pos': 0.6361, 'max_q3_separate': 0.6111}},
    4: {'m_i': {'max_neg': 0.5531, 'max_neg_plus_10': 0.6084, 'max_q3_all': 0.8427, 'max_q2_pos': 0.8771, 'max_q3_separate': 0.9238}, 'v_d': {'max_neg': 0.602, 'max_neg_plus_10': 0.6622, 'max_q3_all': 0.6085, 'max_q2_pos': 0.6398, 'max_q3_separate': 0.61}},
    5: {'m_i': {'max_neg': 0.7392, 'max_neg_plus_10': 0.8132, 'max_q3_all': 0.9038, 'max_q2_pos': 0.9124, 'max_q3_separate': 0.9561}, 'v_d': {'max_neg': 0.6, 'max_neg_plus_10': 0.66, 'max_q3_all': 0.6085, 'max_q2_pos': 0.6411, 'max_q3_separate': 0.6121}},
    6: {'m_i': {'max_neg': 0.645, 'max_neg_plus_10': 0.7095, 'max_q3_all': 0.8827, 'max_q2_pos': 0.8821, 'max_q3_separate': 0.9363}, 'v_d': {'max_neg': 0.6002, 'max_neg_plus_10': 0.6603, 'max_q3_all': 0.6086, 'max_q2_pos': 0.638, 'max_q3_separate': 0.6103}},
    7: {'m_i': {'max_neg': 0.6099, 'max_neg_plus_10': 0.6708, 'max_q3_all': 0.878, 'max_q2_pos': 0.8807, 'max_q3_separate': 0.9476}, 'v_d': {'max_neg': 0.6009, 'max_neg_plus_10': 0.6609, 'max_q3_all': 0.6074, 'max_q2_pos': 0.6457, 'max_q3_separate': 0.6117}},
    8: {'m_i': {'max_neg': 0.5887, 'max_neg_plus_10': 0.6475, 'max_q3_all': 0.8624, 'max_q2_pos': 0.9111, 'max_q3_separate': 0.9383}, 'v_d': {'max_neg': 0.6017, 'max_neg_plus_10': 0.6618, 'max_q3_all': 0.6084, 'max_q2_pos': 0.6464, 'max_q3_separate': 0.6105}},
    9: {'m_i': {'max_neg': 0.4535, 'max_neg_plus_10': 0.4988, 'max_q3_all': 0.8921, 'max_q2_pos': 0.9048, 'max_q3_separate': 0.9595}, 'v_d': {'max_neg': 0.6097, 'max_neg_plus_10': 0.6706, 'max_q3_all': 0.615, 'max_q2_pos': 0.6452, 'max_q3_separate': 0.6155}},
    10: {'m_i': {'max_neg': 0.6832, 'max_neg_plus_10': 0.7515, 'max_q3_all': 0.9068, 'max_q2_pos': 0.9028, 'max_q3_separate': 0.9552}, 'v_d': {'max_neg': 0.6012, 'max_neg_plus_10': 0.6613, 'max_q3_all': 0.6086, 'max_q2_pos': 0.6487, 'max_q3_separate': 0.6143}},
    11: {'m_i': {'max_neg': 0.7556, 'max_neg_plus_10': 0.8312, 'max_q3_all': 0.9167, 'max_q2_pos': 0.8968, 'max_q3_separate': 0.9566}, 'v_d': {'max_neg': 0.6008, 'max_neg_plus_10': 0.6609, 'max_q3_all': 0.6099, 'max_q2_pos': 0.6507, 'max_q3_separate': 0.6153}},
    12: {'m_i': {'max_neg': 0.6463, 'max_neg_plus_10': 0.7109, 'max_q3_all': 0.9086, 'max_q2_pos': 0.8982, 'max_q3_separate': 0.9618}, 'v_d': {'max_neg': 0.6033, 'max_neg_plus_10': 0.6636, 'max_q3_all': 0.6109, 'max_q2_pos': 0.6548, 'max_q3_separate': 0.6158}},
    13: {'m_i': {'max_neg': 0.5716, 'max_neg_plus_10': 0.6287, 'max_q3_all': 0.8666, 'max_q2_pos': 0.897, 'max_q3_separate': 0.9437}, 'v_d': {'max_neg': 0.6019, 'max_neg_plus_10': 0.6621, 'max_q3_all': 0.6106, 'max_q2_pos': 0.6588, 'max_q3_separate': 0.6165}},
    14: {'m_i': {'max_neg': 0.6594, 'max_neg_plus_10': 0.7253, 'max_q3_all': 0.8942, 'max_q2_pos': 0.8824, 'max_q3_separate': 0.9458}, 'v_d': {'max_neg': 0.6024, 'max_neg_plus_10': 0.6627, 'max_q3_all': 0.6133, 'max_q2_pos': 0.6593, 'max_q3_separate': 0.6205}},
    15: {'m_i': {'max_neg': 0.6862, 'max_neg_plus_10': 0.7548, 'max_q3_all': 0.8927, 'max_q2_pos': 0.9092, 'max_q3_separate': 0.9487}, 'v_d': {'max_neg': 0.6009, 'max_neg_plus_10': 0.661, 'max_q3_all': 0.6094, 'max_q2_pos': 0.6569, 'max_q3_separate': 0.6158}},
    16: {'m_i': {'max_neg': 0.4103, 'max_neg_plus_10': 0.4513, 'max_q3_all': 0.8321, 'max_q2_pos': 0.8455, 'max_q3_separate': 0.9405}, 'v_d': {'max_neg': 0.6379, 'max_neg_plus_10': 0.7017, 'max_q3_all': 0.6667, 'max_q2_pos': 0.6619, 'max_q3_separate': 0.6672}},
    17: {'m_i': {'max_neg': 0.5269, 'max_neg_plus_10': 0.5796, 'max_q3_all': 0.9009, 'max_q2_pos': 0.891, 'max_q3_separate': 0.9546}, 'v_d': {'max_neg': 0.6095, 'max_neg_plus_10': 0.6705, 'max_q3_all': 0.6111, 'max_q2_pos': 0.6626, 'max_q3_separate': 0.6191}},
    18: {'m_i': {'max_neg': 0.6679, 'max_neg_plus_10': 0.7347, 'max_q3_all': 0.908, 'max_q2_pos': 0.8819, 'max_q3_separate': 0.9564}, 'v_d': {'max_neg': 0.6001, 'max_neg_plus_10': 0.6601, 'max_q3_all': 0.6101, 'max_q2_pos': 0.6594, 'max_q3_separate': 0.6158}},
    19: {'m_i': {'max_neg': 0.4773, 'max_neg_plus_10': 0.525, 'max_q3_all': 0.7958, 'max_q2_pos': 0.8976, 'max_q3_separate': 0.9304}, 'v_d': {'max_neg': 0.6004, 'max_neg_plus_10': 0.6605, 'max_q3_all': 0.61, 'max_q2_pos': 0.6562, 'max_q3_separate': 0.6166}},
}

# %%
for i in exp_v1_B32.thresholds.keys():
    exp_v1_B32.print_metrics(i, 'adap', 'm_i')

# %%
for i in exp_v1_B32.thresholds.keys():
    exp_v1_B32.print_metrics(i, 'max_q3_separate', 'm_i')

# %%
for dataset in exp_v1_B32.infer_info['dataset'].unique():
    for thr in exp_v1_B32.thresholds[0]['m_i'].keys():
        for it in ['m_i', 'v_d']:
            exp_v1_B32.boxplots_by_dataset(dataset, list(exp_v1_B32.thresholds.keys()), th_name=thr, seg_item=it)

# %%
for i in range(20):
    exp_v1_B32.plot_all_metrics(i, 'adap', 'm_i')

# %% [markdown]
# ### ExpV2 Batch_size=16

# %%
exp_v2_B16 = Experiment('exp_v2_B16')
exp_v2_B16.load_eval_metrics(os.path.join(data_path, "2073339/Test_record/ACL_ViT16_aclifa_2gpu/tensorboard")) # unique-waterfall-33 or olive-sun-36
exp_v2_B16.load_eval_metrics(os.path.join(data_path, "2073339/Test_record_noisy/ACL_ViT16_Exp_ACL_v2/tensorboard"))
exp_v2_B16.load_eval_inference_info(os.path.join(data_path, "2073339/Test_record/ACL_ViT16_aclifa_2gpu/numpy"))

# %%
exp_v2_B16.print_metrics_noisy('all')

# %%
exp_v2_B16.boxplots_by_dataset('vggss', [17, 18, 19], th_name='max_neg_plus_10')

# %%
exp_v2_B16.boxplots_by_dataset('avatar_one', [17, 18, 19], th_name='max_neg_plus_10')

# %%
exp_v2_B16.plot_all_metrics(19)

# %%
# plot_all_experiments(EXPERIMENTS)
