# %%
import sys, os
sys.path.insert(0, os.getcwd())

import numpy as np
import time

# %%
import importlib
import viz_utils
importlib.reload(viz_utils)
from viz_utils import boxplots_by_dataset_compare

import experiment
importlib.reload(experiment)
from experiment import Experiment, print_all_metrics

# %%
import matplotlib.pyplot as plt
from datetime import datetime

# %%
data_path = '/'.join(os.getcwd().split('/')[:-2] + ['train_outputs'])

# %% [markdown]
# ## ACL Experiments

# %% [markdown]
# ### Baseline model with their weights

# %%
Experiment('ACL_baseline').cleanup()

# %%
baseline = Experiment('ACL_baseline')
baseline.load_eval_inference_info(os.path.join(data_path, "2181388/Test_record/ACL_ViT16_Exp_ACL_v1/numpy")) # thresholds for all epochs
baseline.load_eval_inference_info(os.path.join(data_path, "2184833/Test_record/ACL_ViT16_Exp_ACL_v1/numpy")) # standard eval for all epochs
baseline.load_eval_metrics(os.path.join(data_path, "2184833/Test_record/ACL_ViT16_Exp_ACL_v1/tensorboard")) # standard eval for all epochs
baseline.load_eval_metrics(os.path.join(data_path, "2195226/Test_record/ACL_ViT16_Exp_ACL_v1/tensorboard")) # reevaluate with avatar offscreen only
baseline.load_eval_metrics(os.path.join(data_path, "2195291/Test_record/ACL_ViT16_Exp_ACL_v1/tensorboard")) # noisy eval
baseline.load_eval_metrics(os.path.join(data_path, "2214807/Test_record/ACL_ViT16_Exp_ACL_v1/tensorboard")) # pIAs for positive noisy

# %%
# boxplots_by_dataset_compare(
#     [Experiment('baseline')],
#     [20],
#     dataset_name=dataset,
#     seg_item=seg_item,
#     th_name=thresh,
#     min_max='max'
# )

# %%
baseline.print_metrics('adap', 'm_i', snr=True)

# %%
baseline.print_metrics('max_q3_separate', 'm_i', snr=True)

# %%
baseline.print_metrics('adap', 'v_d', snr=True)

# %%
baseline.print_metrics('max_q3_separate', 'v_d', snr=True)

# %%
baseline.boxplots_by_dataset('vggss', ['best'], 'max_q3_separate', 'm_i')

# %%
baseline.boxplots_by_dataset('vggss', ['best'], 'max_q3_separate', 'v_d')

# %%
# baseline.boxplots_by_dataset('avatar_one', ['best'], 'max_neg_plus_10', 'v_d')
# for dataset in baseline.infer_info['dataset'].unique():
#     for thr in baseline.thresholds['best']['m_i'].keys():
#         for it in ['m_i', 'v_d']:
#             baseline.boxplots_by_dataset(dataset, list(baseline.thresholds.keys()), th_name=thr, seg_item=it)
#             time.sleep(1)

# %%
baseline.plot_all_metrics('best', 'adap', 'm_i')

# %%
baseline.plot_all_metrics('best', 'adap', 'v_d')

# %% [markdown]
# ### ExpV1 Batch_size=16

# %%
# Experiment('ACL_v1_B16').cleanup()
ACL_v1_B16 = Experiment('ACL_v1_B16')
ACL_v1_B16.load_eval_inference_info(os.path.join(data_path, "2074301-full/2181729/Test_record/ACL_ViT16_aclifa_2gpu/numpy"))
ACL_v1_B16.load_eval_inference_info(os.path.join(data_path, "2074301-full/2185955/Test_record/ACL_ViT16_aclifa_2gpu/numpy"))
ACL_v1_B16.load_eval_metrics(os.path.join(data_path, "2074301-full/2185955/Test_record/ACL_ViT16_aclifa_2gpu/tensorboard"))
ACL_v1_B16.load_eval_metrics(os.path.join(data_path, "2074301-full/2195227/Test_record/ACL_ViT16_aclifa_2gpu/tensorboard"))
ACL_v1_B16.load_eval_metrics(os.path.join(data_path, "2074301-full/2208246/Test_record/ACL_ViT16_aclifa_2gpu/tensorboard"))
ACL_v1_B16.load_eval_metrics(os.path.join(data_path, "2074301-full/2214808/Test_record/ACL_ViT16_aclifa_2gpu/tensorboard"))

# %%
ACL_v1_B16.print_metrics('adap', 'm_i', snr=True)

# %%
ACL_v1_B16.print_metrics('max_q3_separate', 'm_i', snr=True)

# %%
ACL_v1_B16.print_metrics('adap', 'v_d', snr=True)

# %%
ACL_v1_B16.print_metrics('max_q3_separate', 'v_d', snr=True)

# %%
for dataset in ACL_v1_B16.infer_info['dataset'].unique():
    for thr in ACL_v1_B16.thresholds[0]['m_i'].keys():
        for it in ['m_i', 'v_d']:
            ACL_v1_B16.boxplots_by_dataset(dataset, list(ACL_v1_B16.thresholds.keys()), th_name=thr, seg_item=it)
            time.sleep(1)

# %%
# for i in range(20):
#     ACL_v1_B16.plot_all_metrics(i, 'adap', 'v_d')

# %% [markdown]
# ### ExpV1 Batch_size=32

# %%
ACL_v1_B32 = Experiment('ACL_v1_B32')
ACL_v1_B32.load_eval_inference_info(os.path.join(data_path, "pirineus3/2064866/2182142/Test_record/ACL_ViT16_aclifa_2gpu/numpy"))
ACL_v1_B32.load_eval_inference_info(os.path.join(data_path, "pirineus3/2064866/2186728/Test_record/ACL_ViT16_aclifa_2gpu/numpy"))
ACL_v1_B32.load_eval_metrics(os.path.join(data_path, "pirineus3/2064866/2186728/Test_record/ACL_ViT16_aclifa_2gpu/tensorboard"))
ACL_v1_B32.load_eval_metrics(os.path.join(data_path, "pirineus3/2064866/2195230/Test_record/ACL_ViT16_aclifa_2gpu/tensorboard"))
ACL_v1_B32.load_eval_metrics(os.path.join(data_path, "pirineus3/2064866/2208249/Test_record/ACL_ViT16_aclifa_2gpu/tensorboard"))
ACL_v1_B32.load_eval_metrics(os.path.join(data_path, "pirineus3/2064866/2214811/Test_record/ACL_ViT16_aclifa_2gpu/tensorboard"))

# %%
ACL_v1_B32.print_metrics('adap', 'm_i', snr=True)

# %%
ACL_v1_B32.print_metrics('max_q3_separate', 'm_i', snr=True)

# %%
ACL_v1_B32.print_metrics('adap', 'v_d', snr=True)

# %%
ACL_v1_B32.print_metrics('max_q3_separate', 'v_d', snr=True)

# %%
# for dataset in ACL_v1_B32.infer_info['dataset'].unique():
#     for thr in ACL_v1_B32.thresholds[0]['m_i'].keys():
#         for it in ['m_i', 'v_d']:
#             ACL_v1_B32.boxplots_by_dataset(dataset, list(ACL_v1_B32.thresholds.keys()), th_name=thr, seg_item=it)

# %%
for i in range(20):
    ACL_v1_B32.plot_all_metrics(i, 'adap', 'm_i')

# %% [markdown]
# ### ExpV2 Batch_size=16

# %%
ACL_v2_B16 = Experiment('ACL_v2_B16')
ACL_v2_B16.load_eval_inference_info(os.path.join(data_path, "pirineus3/2168632/2181900/Test_record/ACL_ViT16_aclifa_2gpu/numpy"))
ACL_v2_B16.load_eval_inference_info(os.path.join(data_path, "pirineus3/2168632/2186726/Test_record/ACL_ViT16_aclifa_2gpu/numpy"))
ACL_v2_B16.load_eval_metrics(os.path.join(data_path, "pirineus3/2168632/2186726/Test_record/ACL_ViT16_aclifa_2gpu/tensorboard"))
ACL_v2_B16.load_eval_metrics(os.path.join(data_path, "pirineus3/2168632/2195228/Test_record/ACL_ViT16_aclifa_2gpu/tensorboard"))
ACL_v2_B16.load_eval_metrics(os.path.join(data_path, "pirineus3/2168632/2208247/Test_record/ACL_ViT16_aclifa_2gpu/tensorboard"))
ACL_v2_B16.load_eval_metrics(os.path.join(data_path, "pirineus3/2168632/2214809/Test_record/ACL_ViT16_aclifa_2gpu/tensorboard"))

# %%
ACL_v2_B16.print_metrics('adap', 'm_i', snr=True)

# %%
ACL_v2_B16.print_metrics('max_q3_separate', 'm_i', snr=True)

# %%
ACL_v2_B16.print_metrics('adap', 'v_d', snr=True)

# %%
ACL_v2_B16.print_metrics('max_q3_separate', 'v_d', snr=True)

# %%
# for dataset in ACL_v2_B16.infer_info['dataset'].unique():
#     for thr in ACL_v2_B16.thresholds[0]['m_i'].keys():
#         for it in ['m_i', 'v_d']:
#             ACL_v2_B16.boxplots_by_dataset(dataset, list(ACL_v2_B16.thresholds.keys()), th_name=thr, seg_item=it)

# %% [markdown]
# ### ExpV3 Batch_size=16

# %%
ACL_v3_B16 = Experiment('ACL_v3_B16')
ACL_v3_B16.load_eval_inference_info(os.path.join(data_path, "pirineus3/2210849/2181901/Test_record/ACL_ViT16_aclifa_2gpu/numpy"))
ACL_v3_B16.load_eval_inference_info(os.path.join(data_path, "pirineus3/2210849/2186727/Test_record/ACL_ViT16_aclifa_2gpu/numpy"))
ACL_v3_B16.load_eval_metrics(os.path.join(data_path, "pirineus3/2210849/2186727/Test_record/ACL_ViT16_aclifa_2gpu/tensorboard"))
ACL_v3_B16.load_eval_metrics(os.path.join(data_path, "pirineus3/2210849/2195229/Test_record/ACL_ViT16_aclifa_2gpu/tensorboard"))
ACL_v3_B16.load_eval_metrics(os.path.join(data_path, "pirineus3/2210849/2208248/Test_record/ACL_ViT16_aclifa_2gpu/tensorboard"))
ACL_v3_B16.load_eval_metrics(os.path.join(data_path, "pirineus3/2210849/2214810/Test_record/ACL_ViT16_aclifa_2gpu/tensorboard"))

# %%
ACL_v3_B16.print_metrics('adap', 'm_i', snr=True)

# %%
ACL_v3_B16.print_metrics('max_q3_separate', 'm_i', snr=True)

# %%
ACL_v3_B16.print_metrics('adap', 'v_d', snr=True)

# %%
ACL_v3_B16.print_metrics('max_q3_separate', 'v_d', snr=True)

# %%
for dataset in ACL_v3_B16.infer_info['dataset'].unique():
    for thr in ACL_v3_B16.thresholds[0]['m_i'].keys():
        for it in ['m_i', 'v_d']:
            ACL_v3_B16.boxplots_by_dataset(dataset, list(ACL_v3_B16.thresholds.keys()), th_name=thr, seg_item=it)

# %% [markdown]
# ### ExpV4 Batch_size=16

# %%
ACL_v4_B16 = Experiment('ACL_v4_B16')
ACL_v4_B16.load_eval_inference_info(os.path.join(data_path, "pirineus3/2271991/2184858/Test_record/ACL_ViT16_aclifa_2gpu/numpy"))
ACL_v4_B16.load_eval_inference_info(os.path.join(data_path, "pirineus3/2271991/2186729/Test_record/ACL_ViT16_aclifa_2gpu/numpy"))
ACL_v4_B16.load_eval_metrics(os.path.join(data_path, "pirineus3/2271991/2186729/Test_record/ACL_ViT16_aclifa_2gpu/tensorboard"))
ACL_v4_B16.load_eval_metrics(os.path.join(data_path, "pirineus3/2271991/2195231/Test_record/ACL_ViT16_aclifa_2gpu/tensorboard"))
ACL_v4_B16.load_eval_metrics(os.path.join(data_path, "pirineus3/2271991/2208250/Test_record/ACL_ViT16_aclifa_2gpu/tensorboard"))
ACL_v4_B16.load_eval_metrics(os.path.join(data_path, "pirineus3/2271991/2214812/Test_record/ACL_ViT16_aclifa_2gpu/tensorboard"))

# %%
ACL_v4_B16.print_metrics('adap', 'm_i', snr=True)

# %%
ACL_v4_B16.print_metrics('max_q3_separate', 'm_i', snr=True)

# %%
ACL_v4_B16.print_metrics('adap', 'v_d', snr=True)

# %%
ACL_v4_B16.print_metrics('max_q3_separate', 'v_d', snr=True)

# %%
for dataset in ACL_v4_B16.infer_info['dataset'].unique():
    for thr in ACL_v4_B16.thresholds[0]['m_i'].keys():
        for it in ['m_i', 'v_d']:
            ACL_v4_B16.boxplots_by_dataset(dataset, list(ACL_v4_B16.thresholds.keys()), th_name=thr, seg_item=it)

# %% [markdown]
# ### ExpV5 Batch_size=16

# %%
ACL_v5_B16 = Experiment('ACL_v5_B16')
ACL_v5_B16.load_eval_inference_info(os.path.join(data_path, "pirineus3/2568854/2205553/Test_record/ACL_ViT16_aclifa_2gpu/numpy"))
ACL_v5_B16.load_eval_inference_info(os.path.join(data_path, "pirineus3/2568854/2210817/Test_record/ACL_ViT16_aclifa_2gpu/numpy"))
ACL_v5_B16.load_eval_metrics(os.path.join(data_path, "pirineus3/2568854/2210817/Test_record/ACL_ViT16_aclifa_2gpu/tensorboard"))
ACL_v5_B16.load_eval_metrics(os.path.join(data_path, "pirineus3/2568854/2213770/Test_record/ACL_ViT16_aclifa_2gpu/tensorboard"))
ACL_v5_B16.load_eval_metrics(os.path.join(data_path, "pirineus3/2568854/2214813/Test_record/ACL_ViT16_aclifa_2gpu/tensorboard"))
# one less loaded because here avatar offscreen already in standard eval

# %%
for dataset in ACL_v5_B16.infer_info['dataset'].unique():
    for thr in ACL_v5_B16.thresholds[0]['m_i'].keys():
        for it in ['m_i', 'v_d']:
            ACL_v5_B16.boxplots_by_dataset(dataset, list(ACL_v5_B16.thresholds.keys()), th_name=thr, seg_item=it)

# %%
ACL_v5_B16.print_metrics('adap', 'm_i', snr=False)

# %%
ACL_v5_B16.print_metrics('max_q3_separate', 'm_i', snr=False)

# %%
ACL_v5_B16.print_metrics('adap', 'v_d', snr=False)

# %%
ACL_v5_B16.print_metrics('max_q3_separate', 'v_d', snr=False)

# %% [markdown]
# ## Comparison of experiments

# %%
# plot_all_experiments(EXPERIMENTS)

# %%
experiments_epochs = {
    'ACL_baseline': ['best'],
    'ACL_v1_B16': [17],
    'ACL_v1_B32': [19],
    'ACL_v2_B16': [16],
    'ACL_v3_B16': [15],
    'ACL_v4_B16': [18],
    'ACL_v5_B16': [16],
}

# %%
print_all_metrics(experiments_epochs, 'adap', 'm_i', snr=True)

# %%
print_all_metrics(experiments_epochs, 'max_q3_separate', 'm_i', snr=True)

# %%
experiments = []
epochs = []
for exp, eps in experiments_epochs.items():
    for e in eps:
        experiments.append(Experiment(exp))
        epochs.append(e)

# %%
fig = boxplots_by_dataset_compare(
    experiments,
    epochs,
    'vggss',
    'v_d',
    'max_q3_separate'
)
# fig.suptitle(f'Boxplot comparison between ACL-SaN models w.r.t. audio type (' + r"$\bf{" + 'M' + "}^I$)", fontsize=14)
fig.suptitle(f'Boxplot comparison between ACL-SaN models w.r.t. audio type (' + r"$\bf{" + 'v' + "}^D$)", fontsize=14)
plt.tight_layout()
os.makedirs(f'outputs', exist_ok=True)
fig.savefig(f"outputs/{int(datetime.timestamp(datetime.now()))}.png", bbox_inches='tight', dpi=300)
plt.show()

# %% [markdown]
# ## ADCL Experiments

# %% [markdown]
# ### ExpV1 Batch_size=16

# %%
Experiment('ADCL_v1_B16').cleanup()

# %%
adcl_v1_B16 = Experiment('ADCL_v1_B16')
adcl_v1_B16.load_eval_inference_info(os.path.join(data_path, "2153732/2205581/Test_record/ADCL_ViT16_aclifa_2gpu/numpy"))
# adcl_v1_B16.load_eval_inference_info(os.path.join(data_path, "2153732/2211860/Test_record/ADCL_ViT16_aclifa_2gpu/numpy"))
adcl_v1_B16.load_eval_metrics(os.path.join(data_path, "2153732/2211860/Test_record/ADCL_ViT16_aclifa_2gpu/tensorboard"))

# %%
for dataset in adcl_v1_B16.infer_info['dataset'].unique():
    for thr in adcl_v1_B16.thresholds[0]['m_i'].keys():
        for it in ['m_i', 'v_d']:
            adcl_v1_B16.boxplots_by_dataset(dataset, list(adcl_v1_B16.thresholds.keys()), th_name=thr, seg_item=it)
            time.sleep(1)

# %%
adcl_v1_B16.print_metrics('adap', 'm_i', snr=False)

# %%
adcl_v1_B16.print_metrics('max_q2_pos', 'm_i', snr=False)

# %%
adcl_v1_B16.print_metrics('adap', 'v_d', snr=False)

# %%
adcl_v1_B16.print_metrics('max_q3_separate', 'v_d', snr=False)

# %% [markdown]
# ### Frank

# %%
frank = Experiment('frank')
frank.load_eval_inference_info(os.path.join(data_path, "2074301-full-frank/2213831/Test_record/ACL_ViT16_aclifa_2gpu/numpy"))

# %%
for dataset in frank.infer_info['dataset'].unique():
    for thr in frank.thresholds[0]['m_i'].keys():
        for it in ['m_i', 'v_d']:
            frank.boxplots_by_dataset(dataset, list(frank.thresholds.keys()), th_name=thr, seg_item=it)
            time.sleep(1)
